# %% [markdown]
# # --- Day 13: Knights of the Dinner Table ---
# https://adventofcode.com/2015/day/13

# %%
def getHappinessMap():
    with open("happinessMapping.txt") as file:
        return file.read()

# %%
from collections import defaultdict

# Cleaning happiness map
happinessMapping = getHappinessMap().split("\n")
# Replace lose and gain with negative or empty for simplicity and remove "." at the end
happinessMapping = [x.replace("lose ", "-").replace("gain ", "")[0:-1] for x in happinessMapping]
happinessMapping = [[x.split()[0], x.split()[2], x.split()[-1]] for x in happinessMapping]

# Create dictionary of dictionaries that act as a mapping from each person to their happiness mapping
happinessMap = defaultdict(lambda: defaultdict(int))
for person, effect, person2 in happinessMapping:
    happinessMap[person][person2] = effect

happinessMap
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'Alice': defaultdict(int,
#                          {'Bob': '-57',
#                           'Carol': '-62',
#                           'David': '-75',
#                           'Eric': '71',
#                           'Frank': '-22',
#                           'George': '-23',
#                           'Mallory': '-76'}),
#              'Bob': defaultdict(int,
#                          {'Alice': '-14',
#                           'Carol': '48',
#                           'David': '89',
#                           'Eric': '86',
#                           'Frank': '-2',
#                           'George': '27',
#                           'Mallory': '19'}),
#              'Carol': defaultdict(int,
#                          {'Alice': '37',
#                           'Bob': '45',
#                           'David': '24',
#                           'Eric': '5',
#                           'Frank': '-68',
#                           'George': '-25',
#                           'Mallory': '30'}),
#              'David': defaultdict(int,
#                          {'Alice': '-51',
#                           'Bob': '34',
#                           'Carol': '99',
#                           'Eric': '91',
#                           'Frank': '-38',
#                           'George': '60',
#                           'Mallory': '-63'}),
#              'Eric': defaultdict(int,
#                          {'Alice': '23',
#                           'Bob': '-69',
#                           'Carol': '-33',
#                           'David': '-47',
#                           'Frank': '75',
#                           'George': '82',
#                           'Mallory': '13'}),
#              'Frank': defaultdict(int,
#                          {'Alice': '77',
#                           'Bob': '27',
#                           'Carol': '-87',
#                           'David': '74',
#                           'Eric': '-41',
#                           'George': '-99',
#                           'Mallory': '26'}),
#              'George': defaultdict(int,
#                          {'Alice': '-63',
#                           'Bob': '-51',
#                           'Carol': '-60',
#                           'David': '30',
#                           'Eric': '-100',
#                           'Frank': '-63',
#                           'Mallory': '57'}),
#              'Mallory': defaultdict(int,
#                          {'Alice': '-71',
#                           'Bob': '-28',
#                           'Carol': '-10',
#                           'David': '44',
#                           'Eric': '22',
#                           'Frank': '79',
#                           'George': '-16'})})
