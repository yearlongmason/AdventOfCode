# %% [markdown]
# # --- Day 12: JSAbacusFramework.io ---
# https://adventofcode.com/2015/day/12

# %%
def getJson():
    with open("json.txt") as file: 
        return file.read()

# %%
import re

print(f"Sum of all numbers in json: {sum([int(x) for x in re.findall("-?[0-9]+", getJson())])}")
# Out:
# Sum of all numbers in json: 111754
