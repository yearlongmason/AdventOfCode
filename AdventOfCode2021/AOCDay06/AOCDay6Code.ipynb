# %% [markdown]
# # --- Day 6: Lanternfish ---
# https://adventofcode.com/2021/day/6
#
# The sea floor is getting steeper. Maybe the sleigh keys got carried this way?
#
# A massive school of glowing lanternfish swims past. They must spawn quickly to reach such large numbers - maybe exponentially quickly? You should model their growth rate to be sure.
#
# Although you know nothing about this specific species of lanternfish, you make some guesses about their attributes. Surely, each lanternfish creates a new lanternfish once every 7 days.
#
# However, this process isn't necessarily synchronized between every lanternfish - one lanternfish might have 2 days left until it creates another lanternfish, while another might have 4. So, you can model each fish as a single number that represents the number of days until it creates a new lanternfish.
#
# Furthermore, you reason, a new lanternfish would surely need slightly longer before it's capable of producing more lanternfish: two more days for its first cycle.
#
# So, suppose you have a lanternfish with an internal timer value of 3:
#
# After one day, its internal timer would become 2.
#
# After another day, its internal timer would become 1.
#
# After another day, its internal timer would become 0.
#
# After another day, its internal timer would reset to 6, and it would create a new lanternfish with an internal timer of 8.
#
# After another day, the first lanternfish would have an internal timer of 5, and the second lanternfish would have an internal timer of 7.
#
# A lanternfish that creates a new fish resets its timer to 6, not 7 (because 0 is included as a valid timer value). The new lanternfish starts with an internal timer of 8 and does not start counting down until the next day.
#
# Realizing what you're trying to do, the submarine automatically produces a list of the ages of several hundred nearby lanternfish (your puzzle input).
#
# Each day, a 0 becomes a 6 and adds a new 8 to the end of the list, while each other number decreases by 1 if it was present at the start of the day.
#
# Find a way to simulate lanternfish. How many lanternfish would there be after 80 days?

# %%
import time
def readLanternfish():
    with open('lanternfish.txt') as file:
        return file.read()

def readLanternfishTest():
    with open('lanternfishTest.txt') as file:
        return file.read()    
    
print(readLanternfish())
# Out:
# 1,3,3,4,5,1,1,1,1,1,1,2,1,4,1,1,1,5,2,2,4,3,1,1,2,5,4,2,2,3,1,2,3,2,1,1,4,4,2,4,4,1,2,4,3,3,3,1,1,3,4,5,2,5,1,2,5,1,1,1,3,2,3,3,1,4,1,1,4,1,4,1,1,1,1,5,4,2,1,2,2,5,5,1,1,1,1,2,1,1,1,1,3,2,3,1,4,3,1,1,3,1,1,1,1,3,3,4,5,1,1,5,4,4,4,4,2,5,1,1,2,5,1,3,4,4,1,4,1,5,5,2,4,5,1,1,3,1,3,1,4,1,3,1,2,2,1,5,1,5,1,3,1,3,1,4,1,4,5,1,4,5,1,1,5,2,2,4,5,1,3,2,4,2,1,1,1,2,1,2,1,3,4,4,2,2,4,2,1,4,1,3,1,3,5,3,1,1,2,2,1,5,2,1,1,1,1,1,5,4,3,5,3,3,1,5,5,4,4,2,1,1,1,2,5,3,3,2,1,1,1,5,5,3,1,4,4,2,4,2,1,1,1,5,1,2,4,1,3,4,4,2,1,4,2,1,3,4,3,3,2,3,1,5,3,1,1,5,1,2,2,4,4,1,2,3,1,2,1,1,2,1,1,1,2,3,5,5,1,2,3,1,3,5,4,2,1,3,3,4

# %%
fish = readLanternfish().split(',')

class Lanternfish: #Defines Lanternfish class to represent each lanternfish
    allFish = [] #This will store every instance of a lanternfish
    
    def __init__(self, days=8):
        self.days = days
        Lanternfish.allFish.append(self) #Everytime a new instance of Lanternfish is created it will append it to allFish
    
    def dayPass(self): #This function represents 1 day passing
        self.days -=1
        if self.days == -1:#Checks to see if the lanternfish is ready to create a new lanternfish
            self.days=6 #Resets days
            Lanternfish() #Creates a new instance of Lanternfish that uses the default days value(8)
            
    @classmethod
    def dayPassAll(cls):
        for i in range(len(cls.allFish)): #Goes through each instance of fish
            cls.allFish[i].days-=1 #Subtracts 1 day from the fish's time till reproduction
            if cls.allFish[i].days == -1: #If the fish's timer goes to -1 it reproduces and resets it's days left
                cls.allFish[i].days = 6
                Lanternfish() #Initiates a new instance of Lanternfish that uses the default days value(8)
            
for i in range(len(fish)): #Casts everything in fish as a Lanternfish class
    fish[i] = Lanternfish(int(fish[i]))
        
start = time.time()
days = 80
for i in range(days): #Cycles through 80 days
    Lanternfish.dayPassAll() #Class method version
    '''This is a slower version that goes through every instance and calls the dayPass function on each instance
    for i in range(len(Lanternfish.allFish)): #Goes through every fish for every day
        Lanternfish.allFish[i].dayPass() #Passes a day for each fish
    '''
print(f"Number of lanternfish after {days} days: {len(Lanternfish.allFish)}\nTime to run: {round(time.time() - start,3)} seconds")
# Out:
# Number of lanternfish after 80 days: 363101
# Time to run: 1.053 seconds

# %% [markdown]
# # --- Part Two ---
# Suppose the lanternfish live forever and have unlimited food and space. Would they take over the entire ocean?
#
# After 256 days in the example above, there would be a total of 26984457539 lanternfish!
#
# How many lanternfish would there be after 256 days?

# %%
fish = readLanternfish().split(',')

class Lanternfish: #Defines Lanternfish class to represent each lanternfish
    allFish = [] #This will store every instance of a lanternfish
    
    def __init__(self, days=8):
        self.days = days
        Lanternfish.allFish.append(self) #Everytime a new instance of Lanternfish is created it will append it to allFish
            
    @classmethod
    def dayPass(cls):
        for i in range(len(cls.allFish)):
            cls.allFish[i].days-=1
            if cls.allFish[i].days == -1:
                cls.allFish[i].days = 6
                Lanternfish()
            
for i in range(len(fish)): #Casts everything in fish as a Lanternfish class
    fish[i] = Lanternfish(int(fish[i]))
        
days = 110
totalTime = time.time()
for i in range(days): #Cycles through days
    dayLength = time.time()
    Lanternfish.dayPass()
    print(f"Day {i+1}: {len(Lanternfish.allFish)} lanternfish | Time: {round(time.time() - dayLength,5)} seconds")
        
print(f"""Number of lanternfish after {days} days: {len(Lanternfish.allFish)}
Time to run: {round(time.time() - totalTime,5)} seconds""")
# Out:
# Day 1: 300 lanternfish | Time: 0.0 seconds
# Day 2: 415 lanternfish | Time: 0.0011 seconds
# Day 3: 467 lanternfish | Time: 0.0 seconds
# Day 4: 514 lanternfish | Time: 0.0 seconds
# Day 5: 563 lanternfish | Time: 0.0 seconds
# Day 6: 600 lanternfish | Time: 0.0 seconds
# Day 7: 600 lanternfish | Time: 0.00101 seconds
# Day 8: 600 lanternfish | Time: 8e-05 seconds
# Day 9: 715 lanternfish | Time: 0.0 seconds
# Day 10: 767 lanternfish | Time: 0.0 seconds
# Day 11: 929 lanternfish | Time: 0.00113 seconds
# Day 12: 1030 lanternfish | Time: 0.0 seconds
# Day 13: 1114 lanternfish | Time: 0.0 seconds
# Day 14: 1163 lanternfish | Time: 0.00111 seconds
# Day 15: 1200 lanternfish | Time: 0.0 seconds
# Day 16: 1315 lanternfish | Time: 0.00101 seconds
# Day 17: 1367 lanternfish | Time: 0.0 seconds
# Day 18: 1644 lanternfish | Time: 0.0 seconds
# Day 19: 1797 lanternfish | Time: 0.0 seconds
# Day 20: 2043 lanternfish | Time: 0.0 seconds
# Day 21: 2193 lanternfish | Time: 0.00551 seconds
# Day 22: 2314 lanternfish | Time: 0.0 seconds
# Day 23: 2478 lanternfish | Time: 0.0 seconds
# Day 24: 2567 lanternfish | Time: 0.0 seconds
# Day 25: 2959 lanternfish | Time: 0.0 seconds
# Day 26: 3164 lanternfish | Time: 0.0 seconds
# Day 27: 3687 lanternfish | Time: 0.00803 seconds
# Day 28: 3990 lanternfish | Time: 0.0 seconds
# Day 29: 4357 lanternfish | Time: 0.0 seconds
# Day 30: 4671 lanternfish | Time: 0.0 seconds
# Day 31: 4881 lanternfish | Time: 0.0 seconds
# Day 32: 5437 lanternfish | Time: 0.00801 seconds
# Day 33: 5731 lanternfish | Time: 0.0 seconds
# Day 34: 6646 lanternfish | Time: 0.0 seconds
# Day 35: 7154 lanternfish | Time: 0.008 seconds
# Day 36: 8044 lanternfish | Time: 0.0 seconds
# Day 37: 8661 lanternfish | Time: 0.00799 seconds
# Day 38: 9238 lanternfish | Time: 0.0 seconds
# Day 39: 10108 lanternfish | Time: 0.008 seconds
# Day 40: 10612 lanternfish | Time: 0.0 seconds
# Day 41: 12083 lanternfish | Time: 0.00798 seconds
# Day 42: 12885 lanternfish | Time: 0.0 seconds
# Day 43: 14690 lanternfish | Time: 0.0 seconds
# Day 44: 15815 lanternfish | Time: 0.0 seconds
# Day 45: 17282 lanternfish | Time: 0.00797 seconds
# Day 46: 18769 lanternfish | Time: 0.0 seconds
# Day 47: 19850 lanternfish | Time: 0.0 seconds
# Day 48: 22191 lanternfish | Time: 0.008 seconds
# Day 49: 23497 lanternfish | Time: 0.00801 seconds
# Day 50: 26773 lanternfish | Time: 0.0 seconds
# Day 51: 28700 lanternfish | Time: 0.00798 seconds
# Day 52: 31972 lanternfish | Time: 0.008 seconds
# Day 53: 34584 lanternfish | Time: 0.01599 seconds
# Day 54: 37132 lanternfish | Time: 0.008 seconds
# Day 55: 40960 lanternfish | Time: 0.008 seconds
# Day 56: 43347 lanternfish | Time: 0.01598 seconds
# Day 57: 48964 lanternfish | Time: 0.008 seconds
# Day 58: 52197 lanternfish | Time: 0.01639 seconds
# Day 59: 58745 lanternfish | Time: 0.00844 seconds
# Day 60: 63284 lanternfish | Time: 0.00802 seconds
# Day 61: 69104 lanternfish | Time: 0.016 seconds
# Day 62: 75544 lanternfish | Time: 0.01634 seconds
# Day 63: 80479 lanternfish | Time: 0.02436 seconds
# Day 64: 89924 lanternfish | Time: 0.01599 seconds
# Day 65: 95544 lanternfish | Time: 0.02398 seconds
# Day 66: 107709 lanternfish | Time: 0.01598 seconds
# Day 67: 115481 lanternfish | Time: 0.03199 seconds
# Day 68: 127849 lanternfish | Time: 0.03197 seconds
# Day 69: 138828 lanternfish | Time: 0.03198 seconds
# Day 70: 149583 lanternfish | Time: 0.04861 seconds
# Day 71: 165468 lanternfish | Time: 0.04799 seconds
# Day 72: 176023 lanternfish | Time: 0.04797 seconds
# Day 73: 197633 lanternfish | Time: 0.04797 seconds
# Day 74: 211025 lanternfish | Time: 0.06393 seconds
# Day 75: 235558 lanternfish | Time: 0.09322 seconds
# Day 76: 254309 lanternfish | Time: 0.09891 seconds
# Day 77: 277432 lanternfish | Time: 0.07995 seconds
# Day 78: 304296 lanternfish | Time: 0.09593 seconds
# Day 79: 325606 lanternfish | Time: 0.10394 seconds
# Day 80: 363101 lanternfish | Time: 0.11189 seconds
# Day 81: 387048 lanternfish | Time: 0.11997 seconds
# Day 82: 433191 lanternfish | Time: 0.15987 seconds
# Day 83: 465334 lanternfish | Time: 0.1044 seconds
# Day 84: 512990 lanternfish | Time: 0.16046 seconds
# Day 85: 558605 lanternfish | Time: 0.22385 seconds
# Day 86: 603038 lanternfish | Time: 0.13637 seconds
# Day 87: 667397 lanternfish | Time: 0.15409 seconds
# Day 88: 712654 lanternfish | Time: 0.20877 seconds
# Day 89: 796292 lanternfish | Time: 0.25617 seconds
# Day 90: 852382 lanternfish | Time: 0.22384 seconds
# Day 91: 946181 lanternfish | Time: 0.35973 seconds
# Day 92: 1023939 lanternfish | Time: 0.25662 seconds
# Day 93: 1116028 lanternfish | Time: 0.28119 seconds
# Day 94: 1226002 lanternfish | Time: 0.32158 seconds
# Day 95: 1315692 lanternfish | Time: 0.30562 seconds
# Day 96: 1463689 lanternfish | Time: 0.37782 seconds
# Day 97: 1565036 lanternfish | Time: 0.41755 seconds
# Day 98: 1742473 lanternfish | Time: 0.43438 seconds
# Day 99: 1876321 lanternfish | Time: 0.46507 seconds
# Day 100: 2062209 lanternfish | Time: 0.53122 seconds
# Day 101: 2249941 lanternfish | Time: 0.56219 seconds
# Day 102: 2431720 lanternfish | Time: 0.66382 seconds
# Day 103: 2689691 lanternfish | Time: 0.67352 seconds
# Day 104: 2880728 lanternfish | Time: 0.69889 seconds
# Day 105: 3206162 lanternfish | Time: 0.81214 seconds
# Day 106: 3441357 lanternfish | Time: 0.86791 seconds
# Day 107: 3804682 lanternfish | Time: 0.96429 seconds
# Day 108: 4126262 lanternfish | Time: 1.10805 seconds
# Day 109: 4493929 lanternfish | Time: 1.06031 seconds
# Day 110: 4939632 lanternfish | Time: 1.37778 seconds
# Number of lanternfish after 110 days: 4939632
# Time to run: 15.53208 seconds

# %%
fish = readLanternfish().split(',')
for i in range(len(fish)):
    fish[i] = int(fish[i])

fishQueue = [0,0,0,0,0,0,0,0,0] #Initiates a list with a value of 0 for each amount of days left
for i in fish:
    fishQueue[i] += 1 #Takes the input (fish) and adds 1 to each day value in fishQueue so it has the num of fish per value

def dayPass(fishQueue):
    """Simulates 1 day of lanternfish reproduction"""
    newFish = fishQueue.pop(0) #dequeues the fish that have 0 days (index 0) and assigns it to newFish
    fishQueue.append(newFish) #enqueues the number of new fish to the end which represents 8 days left
    fishQueue[6] += newFish #Adds the number of fish that reset their timers to day 6 (index 6)
    return fishQueue

days = 256
for i in range(days): #Runs the dayPass function once for every simulated day and assigns it to fishQueue
    fishQueue = dayPass(fishQueue)
print(f"Number of lanternfish after {days} days: {sum(fishQueue)}")
# Out:
# Number of lanternfish after 256 days: 1644286074024
